# %%
import requests
import pandas as pd

# %%
url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'
req = requests.get(url)
html = req.text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# %%
movie_list = soup.find_all("td", class_="title")
movie_list
# Out:
# [<td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=190320" title="보이스">보이스</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=199860" title="기적">기적</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=187348" title="샹치와 텐 링즈의 전설">샹치와 텐 링즈의 전설</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=207370" title="말리그넌트">말리그넌트</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=200894" title="극장판 포켓몬스터: 정글의 아이, 코코">극장판 포켓몬스터: 정글의 아이, 코코</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=188472" title="싱크홀">싱크홀</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=192150" title="모가디슈">모가디슈</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=190725" title="캔디맨">캔디맨</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=200065" title="올드">올드</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=204496" title="랑종">랑종</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=205968" title="극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들">극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=205845" title="인피니트">인피니트</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=185614" title="인질">인질</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=202673" title="아임 유어 맨">아임 유어 맨</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=198497" title="최선의 삶">최선의 삶</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=201073" title="코다">코다</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=99702" title="007 노 타임 투 다이">007 노 타임 투 다이</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=30688" title="해리 포터와 마법사의 돌">해리 포터와 마법사의 돌</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=167403" title="맨 인 더 다크 2 ">맨 인 더 다크 2 </a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=204175" title="습도 다소 높음">습도 다소 높음</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=193194" title="도굴">도굴</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=187323" title="베놈 2: 렛 데어 비 카니지">베놈 2: 렛 데어 비 카니지</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=189069" title="다만 악에서 구하소서">다만 악에서 구하소서</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=206177" title="공작조: 현애지상">공작조: 현애지상</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=192620" title="비와 당신의 이야기">비와 당신의 이야기</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=189124" title="미션 파서블">미션 파서블</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=187310" title="미나리">미나리</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=198623" title="좋은 사람">좋은 사람</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=183866" title="담보">담보</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=206168" title="귀문">귀문</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=191548" title="이스케이프 룸 2: 노 웨이 아웃">이스케이프 룸 2: 노 웨이 아웃</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=194463" title="아이">아이</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=189075" title="자산어보">자산어보</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=201724" title="영화의 거리">영화의 거리</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=201718" title="수색자">수색자</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=185917" title="반도">반도</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=201559" title="토베 얀손">토베 얀손</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=186114" title="밥정">밥정</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=209286" title="케이트">케이트</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=207474" title="디스트릭트 666: 영혼의 구역">디스트릭트 666: 영혼의 구역</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=164143" title="이웃사촌">이웃사촌</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=12543" title="말괄량이 삐삐">말괄량이 삐삐</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=201680" title="귀멸의 칼날: 남매의 연">귀멸의 칼날: 남매의 연</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=207284" title="용과 주근깨 공주">용과 주근깨 공주</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=184318" title="블랙 위도우">블랙 위도우</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=191559" title="듄">듄</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=165287" title="검객">검객</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=120165" title="해어화">해어화</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=193966" title="레미니센스">레미니센스</a>
#  </div>
#  </td>, <td class="title">
#  <div class="tit3">
#  <a href="/movie/bi/mi/basic.naver?code=167569" title="더 수어사이드 스쿼드">더 수어사이드 스쿼드</a>
#  </div>
#  </td>]

# %%
titles = []
for movie in movie_list:
    top_list = movie.get_text()[2:-2]
    titles.append(top_list)
titles
# Out:
# ['보이스',
#  '기적',
#  '샹치와 텐 링즈의 전설',
#  '말리그넌트',
#  '극장판 포켓몬스터: 정글의 아이, 코코',
#  '싱크홀',
#  '모가디슈',
#  '캔디맨',
#  '올드',
#  '랑종',
#  '극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들',
#  '인피니트',
#  '인질',
#  '아임 유어 맨',
#  '최선의 삶',
#  '코다',
#  '007 노 타임 투 다이',
#  '해리 포터와 마법사의 돌',
#  '맨 인 더 다크 2 ',
#  '습도 다소 높음',
#  '도굴',
#  '베놈 2: 렛 데어 비 카니지',
#  '다만 악에서 구하소서',
#  '공작조: 현애지상',
#  '비와 당신의 이야기',
#  '미션 파서블',
#  '미나리',
#  '좋은 사람',
#  '담보',
#  '귀문',
#  '이스케이프 룸 2: 노 웨이 아웃',
#  '아이',
#  '자산어보',
#  '영화의 거리',
#  '수색자',
#  '반도',
#  '토베 얀손',
#  '밥정',
#  '케이트',
#  '디스트릭트 666: 영혼의 구역',
#  '이웃사촌',
#  '말괄량이 삐삐',
#  '귀멸의 칼날: 남매의 연',
#  '용과 주근깨 공주',
#  '블랙 위도우',
#  '듄',
#  '검객',
#  '해어화',
#  '레미니센스',
#  '더 수어사이드 스쿼드']

# %%
@app.get('/movies/')
def get_movies(top:int=10):
  movie_liest = ['df', 'cc', 'ad']

result = ''
for i in range(top):
  result += "%d: %s\n"%((i+1), moive_list[i])
  
  return result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8522b023945c> in <module>()
# ----> 1 @app.get('/movies/')
#       2 def get_movies(top:int=10):
#       3   movie_liest = ['df', 'cc', 'ad']
#       4
#       5 result = ''
#
# NameError: name 'app' is not defined
